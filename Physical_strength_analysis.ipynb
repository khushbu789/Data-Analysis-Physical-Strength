# %%
# !pip install pandas

# %%
import pandas as pd
df=pd.read_csv('Physical Strength.csv')
df.head()
# Out:
#    p_id  age  female  ethnicity  grip  chest  e_anx_1  e_anx_2  e_anx_3  \
# 0   103   21       0          8    52   31.0        6        6        6
# 1   183   20       0          8    34   38.0        5        3        5
# 2   177   19       0          1    48   32.0        5        5        4
# 3   133   19       0          1    48   30.0        5        5        3
# 4   171   18       0          2    40   40.0        4        4        5
#
#    e_anx_4  ...  e_sen_1  e_sen_2  e_sen_3  e_sen_4  e_sen_5  e_sen_6  \
# 0        7  ...        2        4        2        1        1        6
# 1        4  ...        4        4        3        3        4        3
# 2        2  ...        3        3        1        4        3        7
# 3        4  ...        4        4        2        3        4        7
# 4        5  ...        3        3        2        4        3        2
#
#    e_sen_7  e_sen_8  e_sen_9  e_sen_10
# 0        7        2        6         5
# ...

# %%
df['r1.1']=df['e_anx_1']

df.head()
# Out:
#    p_id  age  female  ethnicity  grip  chest  e_anx_1  e_anx_2  e_anx_3  \
# 0   103   21       0          8    52   31.0        6        6        6
# 1   183   20       0          8    34   38.0        5        3        5
# 2   177   19       0          1    48   32.0        5        5        4
# 3   133   19       0          1    48   30.0        5        5        3
# 4   171   18       0          2    40   40.0        4        4        5
#
#    e_anx_4  ...  e_sen_2  e_sen_3  e_sen_4  e_sen_5  e_sen_6  e_sen_7  \
# 0        7  ...        4        2        1        1        6        7
# 1        4  ...        4        3        3        4        3        3
# 2        2  ...        3        1        4        3        7        2
# 3        4  ...        4        2        3        4        7        7
# 4        5  ...        3        2        4        3        2        3
#
#    e_sen_8  e_sen_9  e_sen_10  r1.1
# 0        2        6         5     6
# 1        4        4         4     5
# ...

# %%
df['r1.1']=df['e_anx_1']
df['r1.2']=df['e_anx_2']
df['r1.3']=df['e_anx_3']
df['r1.4']=df['e_anx_4']

df['r2.1']=df['e_anx_5']
df['r2.2']=df['e_anx_6']
df['r2.3']=df['e_anx_7']
df['r2.4']=df['e_anx_8']

df['r3.1']=df['e_anx_9']
df['r3.2']=df['e_anx_10']
df['r3.3']=df['e_dep_1']
df['r3.4']=df['e_dep_2']

df['r4.1']=df['e_dep_3']
df['r4.2']=df['e_dep_4']
df['r4.3']=df['e_dep_5']
df['r4.4']=df['e_dep_6']

df['r5.1']=df['e_dep_7']
df['r5.2']=df['e_dep_8']
df['r5.3']=df['e_dep_9']
df['r5.4']=df['e_dep_10']

df['r6.1']=df['e_fear_1']
df['r6.2']=df['e_fear_2']
df['r6.3']=df['e_fear_3']
df['r6.4']=df['e_fear_4']

df['r7.1']=df['e_fear_5']
df['r7.2']=df['e_fear_6']
df['r7.3']=df['e_fear_7']
df['r7.4']=df['e_fear_8']

df['r8.1']=df['e_fear_9']
df['r8.2']=df['e_fear_10']
df['r8.3']=df['e_sen_1']
df['r8.4']=df['e_sen_2']


df['r9.1']=df['e_sen_3']
df['r9.2']=df['e_sen_4']
df['r9.3']=df['e_sen_5']
df['r9.4']=df['e_sen_6']

df['r10.1']=df['e_sen_7']
df['r10.2']=df['e_sen_8']
df['r10.3']=df['e_sen_9']
df['r10.4']=df['e_sen_10']


df.drop('e_anx_1',inplace=True,axis=1)
df.drop('e_anx_2',inplace=True,axis=1)
df.drop('e_anx_3',inplace=True,axis=1)
df.drop('e_anx_4',inplace=True,axis=1)
df.drop('e_anx_5',inplace=True,axis=1)
df.drop('e_anx_6',inplace=True,axis=1)
df.drop('e_anx_7',inplace=True,axis=1)
df.drop('e_anx_8',inplace=True,axis=1)
df.drop('e_anx_9',inplace=True,axis=1)
df.drop('e_anx_10',inplace=True,axis=1)


df.drop('e_dep_1',inplace=True,axis=1)
df.drop('e_dep_2',inplace=True,axis=1)
df.drop('e_dep_3',inplace=True,axis=1)
df.drop('e_dep_4',inplace=True,axis=1)
df.drop('e_dep_5',inplace=True,axis=1)
df.drop('e_dep_6',inplace=True,axis=1)
df.drop('e_dep_7',inplace=True,axis=1)
df.drop('e_dep_8',inplace=True,axis=1)
df.drop('e_dep_9',inplace=True,axis=1)
df.drop('e_dep_10',inplace=True,axis=1)


df.drop('e_fear_1',inplace=True,axis=1)
df.drop('e_fear_2',inplace=True,axis=1)
df.drop('e_fear_3',inplace=True,axis=1)
df.drop('e_fear_4',inplace=True,axis=1)
df.drop('e_fear_5',inplace=True,axis=1)
df.drop('e_fear_6',inplace=True,axis=1)
df.drop('e_fear_7',inplace=True,axis=1)
df.drop('e_fear_8',inplace=True,axis=1)
df.drop('e_fear_9',inplace=True,axis=1)
df.drop('e_fear_10',inplace=True,axis=1)

df.drop('e_sen_1',inplace=True,axis=1)
df.drop('e_sen_2',inplace=True,axis=1)
df.drop('e_sen_3',inplace=True,axis=1)
df.drop('e_sen_4',inplace=True,axis=1)
df.drop('e_sen_5',inplace=True,axis=1)
df.drop('e_sen_6',inplace=True,axis=1)
df.drop('e_sen_7',inplace=True,axis=1)
df.drop('e_sen_8',inplace=True,axis=1)
df.drop('e_sen_9',inplace=True,axis=1)
df.drop('e_sen_10',inplace=True,axis=1)

# %%
df.head()
# Out:
#    p_id  age  female  ethnicity  grip  chest  r1.1  r1.2  r1.3  r1.4  ...  \
# 0   103   21       0          8    52   31.0     6     6     6     7  ...
# 1   183   20       0          8    34   38.0     5     3     5     4  ...
# 2   177   19       0          1    48   32.0     5     5     4     2  ...
# 3   133   19       0          1    48   30.0     5     5     3     4  ...
# 4   171   18       0          2    40   40.0     4     4     5     5  ...
#
#    r8.3  r8.4  r9.1  r9.2  r9.3  r9.4  r10.1  r10.2  r10.3  r10.4
# 0     2     4     2     1     1     6      7      2      6      5
# 1     4     4     3     3     4     3      3      4      4      4
# 2     3     3     1     4     3     7      2      4      4      4
# 3     4     4     2     3     4     7      7      4      3      4
# 4     3     3     2     4     3     2      3      4      5      4
#
# [5 rows x 46 columns]

# %%
df['anxiety_avg']=(df['r1.1']+df['r2.1']+df['r3.1']+df['r4.1']+df['r5.1']+df['r6.1']+df['r7.1']+df['r8.1']+df['r9.1']+df['r10.1'])/10
df.head()
# Out:
#    p_id  age  female  ethnicity  grip  chest  r1.1  r1.2  r1.3  r1.4  ...  \
# 0   103   21       0          8    52   31.0     6     6     6     7  ...
# 1   183   20       0          8    34   38.0     5     3     5     4  ...
# 2   177   19       0          1    48   32.0     5     5     4     2  ...
# 3   133   19       0          1    48   30.0     5     5     3     4  ...
# 4   171   18       0          2    40   40.0     4     4     5     5  ...
#
#    r8.4  r9.1  r9.2  r9.3  r9.4  r10.1  r10.2  r10.3  r10.4  anxiety_avg
# 0     4     2     1     1     6      7      2      6      5          4.6
# 1     4     3     3     4     3      3      4      4      4          4.3
# 2     3     1     4     3     7      2      4      4      4          3.6
# 3     4     2     3     4     7      7      4      3      4          3.6
# 4     3     2     4     3     2      3      4      5      4          3.4
#
# [5 rows x 47 columns]

# %%
df['fear_avg']=(df['r1.2']+df['r2.2']+df['r3.2']+df['r4.2']+df['r5.2']+df['r6.2']+df['r7.2']+df['r8.2']+df['r9.2']+df['r10.2'])/10
df['dep_avg']=(df['r1.3']+df['r2.3']+df['r3.3']+df['r4.3']+df['r5.3']+df['r6.3']+df['r7.3']+df['r8.3']+df['r9.3']+df['r10.3'])/10
df['sen_avg']=(df['r1.4']+df['r2.4']+df['r3.4']+df['r4.4']+df['r5.4']+df['r6.4']+df['r7.4']+df['r8.4']+df['r9.4']+df['r10.4'])/10


df.drop('r1.1',inplace=True,axis=1)
df.drop('r1.2',inplace=True,axis=1)
df.drop('r1.3',inplace=True,axis=1)
df.drop('r1.4',inplace=True,axis=1)

df.drop('r2.1',inplace=True,axis=1)
df.drop('r2.2',inplace=True,axis=1)
df.drop('r2.3',inplace=True,axis=1)
df.drop('r2.4',inplace=True,axis=1)

df.drop('r3.1',inplace=True,axis=1)
df.drop('r3.2',inplace=True,axis=1)
df.drop('r3.3',inplace=True,axis=1)
df.drop('r3.4',inplace=True,axis=1)

df.drop('r4.1',inplace=True,axis=1)
df.drop('r4.2',inplace=True,axis=1)
df.drop('r4.3',inplace=True,axis=1)
df.drop('r4.4',inplace=True,axis=1)


df.drop('r5.1',inplace=True,axis=1)
df.drop('r5.2',inplace=True,axis=1)
df.drop('r5.3',inplace=True,axis=1)
df.drop('r5.4',inplace=True,axis=1)

df.drop('r6.1',inplace=True,axis=1)
df.drop('r6.2',inplace=True,axis=1)
df.drop('r6.3',inplace=True,axis=1)
df.drop('r6.4',inplace=True,axis=1)

df.drop('r7.1',inplace=True,axis=1)
df.drop('r7.2',inplace=True,axis=1)
df.drop('r7.3',inplace=True,axis=1)
df.drop('r7.4',inplace=True,axis=1)

df.drop('r8.1',inplace=True,axis=1)
df.drop('r8.2',inplace=True,axis=1)
df.drop('r8.3',inplace=True,axis=1)
df.drop('r8.4',inplace=True,axis=1)

df.drop('r9.1',inplace=True,axis=1)
df.drop('r9.2',inplace=True,axis=1)
df.drop('r9.3',inplace=True,axis=1)
df.drop('r9.4',inplace=True,axis=1)


df.drop('r10.1',inplace=True,axis=1)
df.drop('r10.2',inplace=True,axis=1)
df.drop('r10.3',inplace=True,axis=1)
df.drop('r10.4',inplace=True,axis=1)

# %%
df
# Out:
#      p_id  age  female  ethnicity  grip  chest  anxiety_avg  fear_avg  \
# 0     103   21       0          8    52   31.0          4.6       3.4
# 1     183   20       0          8    34   38.0          4.3       3.6
# 2     177   19       0          1    48   32.0          3.6       4.1
# 3     133   19       0          1    48   30.0          3.6       3.5
# 4     171   18       0          2    40   40.0          3.4       4.2
# ..    ...  ...     ...        ...   ...    ...          ...       ...
# 170   343   18       1          8    31   20.0          4.3       3.5
# 171   350   22       1          1    25   15.0          3.5       5.1
# 172   355   18       1          8    30   18.0          2.8       3.5
# 173   361   19       1          1    30   23.0          4.8       4.5
# 174   384   19       1          1    28   13.0          3.9       3.9
#
#      dep_avg  sen_avg
# 0        3.6      4.6
# 1        3.9      3.9
# 2        4.0      4.2
# 3        4.2      4.4
# ...

# %%
df['gender']=df['female']
df.drop('female',inplace=True,axis=1)
df
# Out:
#      p_id  age  ethnicity  grip  chest  anxiety_avg  fear_avg  dep_avg  \
# 0     103   21          8    52   31.0          4.6       3.4      3.6
# 1     183   20          8    34   38.0          4.3       3.6      3.9
# 2     177   19          1    48   32.0          3.6       4.1      4.0
# 3     133   19          1    48   30.0          3.6       3.5      4.2
# 4     171   18          2    40   40.0          3.4       4.2      4.0
# ..    ...  ...        ...   ...    ...          ...       ...      ...
# 170   343   18          8    31   20.0          4.3       3.5      4.1
# 171   350   22          1    25   15.0          3.5       5.1      4.7
# 172   355   18          8    30   18.0          2.8       3.5      3.5
# 173   361   19          1    30   23.0          4.8       4.5      4.1
# 174   384   19          1    28   13.0          3.9       3.9      4.0
#
#      sen_avg  gender
# 0        4.6       0
# 1        3.9       0
# 2        4.2       0
# 3        4.4       0
# ...

# %%
df['gender']=df['gender'].replace(["0","1"],["Male","Female"])

# %%
df
# Out:
#      p_id  age  ethnicity  grip  chest  anxiety_avg  fear_avg  dep_avg  \
# 0     103   21          8    52   31.0          4.6       3.4      3.6
# 1     183   20          8    34   38.0          4.3       3.6      3.9
# 2     177   19          1    48   32.0          3.6       4.1      4.0
# 3     133   19          1    48   30.0          3.6       3.5      4.2
# 4     171   18          2    40   40.0          3.4       4.2      4.0
# ..    ...  ...        ...   ...    ...          ...       ...      ...
# 170   343   18          8    31   20.0          4.3       3.5      4.1
# 171   350   22          1    25   15.0          3.5       5.1      4.7
# 172   355   18          8    30   18.0          2.8       3.5      3.5
# 173   361   19          1    30   23.0          4.8       4.5      4.1
# 174   384   19          1    28   13.0          3.9       3.9      4.0
#
#      sen_avg  gender
# 0        4.6       0
# 1        3.9       0
# 2        4.2       0
# 3        4.4       0
# ...

# %%
df['gender']=df['gender'].replace([0,1],["Male","Female"])
df
# Out:
#      p_id  age  ethnicity  grip  chest  anxiety_avg  fear_avg  dep_avg  \
# 0     103   21          8    52   31.0          4.6       3.4      3.6
# 1     183   20          8    34   38.0          4.3       3.6      3.9
# 2     177   19          1    48   32.0          3.6       4.1      4.0
# 3     133   19          1    48   30.0          3.6       3.5      4.2
# 4     171   18          2    40   40.0          3.4       4.2      4.0
# ..    ...  ...        ...   ...    ...          ...       ...      ...
# 170   343   18          8    31   20.0          4.3       3.5      4.1
# 171   350   22          1    25   15.0          3.5       5.1      4.7
# 172   355   18          8    30   18.0          2.8       3.5      3.5
# 173   361   19          1    30   23.0          4.8       4.5      4.1
# 174   384   19          1    28   13.0          3.9       3.9      4.0
#
#      sen_avg  gender
# 0        4.6    Male
# 1        3.9    Male
# 2        4.2    Male
# 3        4.4    Male
# ...

# %%
df.dropna(inplace=False,axis=0)
df
# Out:
#      p_id  age  ethnicity  grip  chest  anxiety_avg  fear_avg  dep_avg  \
# 0     103   21          8    52   31.0          4.6       3.4      3.6
# 1     183   20          8    34   38.0          4.3       3.6      3.9
# 2     177   19          1    48   32.0          3.6       4.1      4.0
# 3     133   19          1    48   30.0          3.6       3.5      4.2
# 4     171   18          2    40   40.0          3.4       4.2      4.0
# ..    ...  ...        ...   ...    ...          ...       ...      ...
# 170   343   18          8    31   20.0          4.3       3.5      4.1
# 171   350   22          1    25   15.0          3.5       5.1      4.7
# 172   355   18          8    30   18.0          2.8       3.5      3.5
# 173   361   19          1    30   23.0          4.8       4.5      4.1
# 174   384   19          1    28   13.0          3.9       3.9      4.0
#
#      sen_avg  gender
# 0        4.6    Male
# 1        3.9    Male
# 2        4.2    Male
# 3        4.4    Male
# ...

# %%
# !pip install seaborn

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

sns.relplot(x='fear_avg',y='anxiety_avg',data=df,col="gender",size="dep_avg",palette=sns.color_palette(["red","yellow","blue","orange","violet","indigo","green","black","grey","pink"]),hue="age",kind="scatter")
plt.show()

# %%
x=sns.catplot(x='dep_avg',y='sen_avg',data=df,aspect=3,col="gender",size=10,palette=sns.color_palette(["red","yellow","blue","orange","violet","indigo","green","black","grey","pink"]),hue="age",kind="strip")
x.set_xticklabels(rotation=30)
plt.show()

# %%
import mysql.connector

# %%
# mydB=mysql.connector.connect(
# host='localhost',
# user='khushbu',
# passwd='root',
# database='health'
# )

# %%
# print(mydB)

# %%
# cur=mydB.cursor()

# %%
mydB=mysql.connector.connect(
host='localhost',
user='khushbu',
passwd='root',
database='health'
)
cur=mydB.cursor(buffered=True)

# %%
# cur.execute("create table physicalstrength (gender varchar (100),age int (3),anxiety_avg float(2),fear_avg float(2),dep_avg float(2),sen_avg float(2))")

df['fear_avg'][0]
# Out:
# 3.4

# %%
# print(df.loc[[84]])
# sql="insert into physicalstrength(gender,age,anxiety_avg,fear_avg,dep_avg,sen_avg) values (%s,%s,%s,%s,%s,%s)"
# values1=("female",int(df['age'][1]),df['anxiety_avg'][1],23.3,2.3,2.3)
# cur.execute(sql,values1)



for i in range(len(df)):
    sql="insert into physicalstrength (gender,age,anxiety_avg,fear_avg,dep_avg,sen_avg) values (%s,%s,%s,%s,%s,%s)"
    values1 =(df['gender'][i],int(df['age'][i]),df['anxiety_avg'][i],df['fear_avg'][i],df['dep_avg'][i],df['sen_avg'][i])
    cur.execute(sql,values1)
    mydB.commit()
# #     print(sql,values1,i)

# %%
cur.execute("select * from physicalstrength")
result=cur.fetchall()

for i in result:
    print(i)
# Out:
# ('Male', 21, 4.6, 3.4, 3.6, 4.6)
# ('Male', 20, 4.3, 3.6, 3.9, 3.9)
# ('Male', 19, 3.6, 4.1, 4.0, 4.2)
# ('Male', 19, 3.6, 3.5, 4.2, 4.4)
# ('Male', 18, 3.4, 4.2, 4.0, 4.1)
# ('Male', 20, 3.3, 4.0, 3.8, 4.3)
# ('Male', 18, 5.0, 4.2, 4.3, 3.9)
# ('Male', 19, 4.1, 4.2, 4.0, 4.0)
# ('Male', 19, 4.4, 3.9, 4.1, 4.7)
# ('Male', 21, 3.7, 3.2, 3.6, 4.1)
# ('Male', 19, 4.6, 4.0, 4.4, 4.3)
# ('Male', 19, 4.0, 3.1, 4.4, 4.1)
# ('Male', 18, 4.6, 3.4, 4.0, 4.0)
# ('Male', 20, 4.3, 4.1, 3.8, 3.4)
# ('Male', 19, 3.3, 3.1, 3.6, 3.4)
# ('Male', 19, 3.1, 3.9, 3.5, 4.6)
# ('Male', 19, 4.5, 3.3, 2.8, 3.6)
# ('Male', 19, 4.0, 3.9, 4.5, 3.3)
# ('Male', 18, 4.6, 4.4, 3.6, 4.2)
# ('Male', 20, 2.7, 3.5, 3.6, 3.5)
# ('Male', 18, 3.3, 3.5, 3.6, 4.1)
# ('Male', 19, 2.8, 3.5, 3.8, 4.9)
# ('Male', 19, 3.2, 3.2, 2.5, 4.3)
# ('Male', 19, 3.8, 3.1, 2.8, 3.0)
# ('Male', 18, 4.0, 4.1, 4.4, 4.4)
# ('Male', 18, 3.4, 4.1, 3.8, 3.6)
# ('Male', 19, 4.0, 4.0, 4.5, 3.6)
# ('Male', 23, 4.0, 3.7, 4.6, 3.9)
# ...
